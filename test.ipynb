# %%
% matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import matplotlib as mpl

# %%
mpl.rc('font', family = 'Noto Sans CJK TC')

# %%
[f.name for f in mpl.font_manager.fontManager.ttflist]
# Out:
# ['DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'STIXSizeFourSym',
#  'cmtt10',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'STIXSizeFiveSym',
#  'STIXSizeThreeSym',
#  'cmr10',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'cmss10',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Serif Display',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Sans Display',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'cmmi10',
#  'cmex10',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'cmsy10',
#  'STIXSizeFourSym',
#  'STIXSizeTwoSym',
#  'cmb10',
#  'DejaVu Serif',
#  'Calibri',
#  'CSong3HK',
#  'Monotype Sorts',
#  'Bookman Old Style',
#  'BrowalliaUPC',
#  'Vijaya',
#  'HanWangYanKai',
#  'Segoe UI',
#  'Albany AMT',
#  'HanWangHeiLight',
#  'Californian FB',
#  'HanWangWCL04',
#  'Garamond',
#  'Lucida Fax',
#  'Jokerman',
#  'High Tower Text',
#  'Minion Pro',
#  'Myriad Pro',
#  'AR BLANCA',
#  'Noto Sans Mono CJK TC',
#  'Adobe Hebrew',
#  'Minion Pro',
#  'Myriad Pro',
#  'AngsanaUPC',
#  'Adobe Fan Heiti Std',
#  'Goudy Old Style',
#  'JasmineUPC',
#  'Malgun Gothic',
#  'Mongolian Baiti',
#  'Latha',
#  'Vrinda',
#  'Lucida Sans Typewriter',
#  'Book Antiqua',
#  'Nirmala UI',
#  'Orator Std',
#  'HanWang KaiBold-Gb5',
#  'Iskoola Pota',
#  'Cambria',
#  'Perpetua',
#  'Chaparral Pro',
#  'Noto Sans CJK TC',
#  'Kokila',
#  'Kozuka Gothic Pro',
#  'BrowalliaUPC',
#  'Adobe Caslon Pro',
#  'Kristen ITC',
#  'Verdana',
#  'Haettenschweiler',
#  'HanWangYenHeavy',
#  'HP Simplified',
#  'Bookman Old Style',
#  'FreesiaUPC',
#  'Cooper Black',
#  'Lao UI',
#  'Book Antiqua',
#  'Kozuka Gothic Pro',
#  'Franklin Gothic Book',
#  'Kokila',
#  'FrankRuehl',
#  'HanWangWCL03',
#  'Avenir Next Cyr W04 Light It',
#  'HanWangWCL10',
#  'Bodoni MT',
#  'Arial',
#  'Avenir Next Cyr W04',
#  'Elephant',
#  'Noto Sans Mono CJK TC',
#  'HanWangWCL04',
#  'Berlin Sans FB',
#  'Century Gothic',
#  'Kozuka Mincho Pro',
#  'AngsanaUPC',
#  'MS Reference Sans Serif',
#  'TypeLand KhangXi Dict Trial',
#  'Century Schoolbook',
#  'Birch Std',
#  'Trajan Pro',
#  'MoolBoran',
#  'Microsoft New Tai Lue',
#  'Curlz MT',
#  'Niagara Engraved',
#  'Adobe Ming Std',
#  'Palace Script MT',
#  'Cordia New',
#  'Chaparral Pro',
#  'HP Simplified',
#  'Yu Mincho',
#  'Juice ITC',
#  'Berlin Sans FB',
#  'Footlight MT Light',
#  'Giddyup Std',
#  'Tw Cen MT',
#  'HanWangMingLight',
#  'Perpetua',
#  'HanWangWCL02',
#  'Agency FB',
#  'Tw Cen MT Condensed',
#  'Traditional Arabic',
#  'Segoe UI',
#  'Segoe Print',
#  'Javanese Text',
#  'Angsana New',
#  'Arial Symbol',
#  'Symbol MT',
#  'Noto Sans CJK TC',
#  'Raavi',
#  'Aparajita',
#  'Lao UI',
#  'Calisto MT',
#  'Modern No. 20',
#  'HanWangLiSuMedium',
#  'Californian FB',
#  'Brush Script Std',
#  'MS Outlook',
#  'Niagara Engraved',
#  'Britannic Bold',
#  'Cooper Std',
#  'Times New Roman Symbol',
#  'OCR A Extended',
#  'AR JULIAN',
#  'Adobe Caslon Pro',
#  'Constantia',
#  'Elephant',
#  'Arabic Typesetting',
#  'Consolas',
#  'Kozuka Mincho Pr6N',
#  'Segoe UI',
#  'Snap ITC',
#  'Myanmar Text',
#  'Gill Sans MT Condensed',
#  'Trebuchet MS',
#  'Agency FB',
#  'Letter Gothic Std',
#  'DilleniaUPC',
#  'Goudy Stout',
#  'HanWangFangSongMedium',
#  'HanWangGB06',
#  'Franklin Gothic Heavy',
#  'Franklin Gothic Medium Cond',
#  'WenYue GuDianMingChaoTi (Non-Commercial Use)',
#  'Thorndale AMT',
#  'Myriad Pro',
#  'Chiller',
#  'Plantagenet Cherokee',
#  'Tw Cen MT',
#  'Adobe Gothic Std',
#  'Georgia',
#  'Stencil',
#  'Adobe Gothic Std',
#  'SimHei',
#  'Myriad Pro',
#  'HanWangWCL02',
#  'Arial Symbol',
#  'Kozuka Mincho Pro',
#  'Wingdings 2',
#  'Bookman Old Style',
#  'Kozuka Gothic Pr6N',
#  'CSongGB18030C-LightHWL',
#  'DilleniaUPC',
#  'Broadway',
#  'Mistral',
#  'Georgia',
#  'HanWang FangSongMedium-Gb5',
#  'Rockwell',
#  'Angsana New',
#  'Times New Roman Symbol',
#  'Kozuka Mincho Pro',
#  'Poor Richard',
#  'Euphemia',
#  'Adobe Caslon Pro',
#  'SimSun-ExtB',
#  'Segoe UI Emoji',
#  'Franklin Gothic Medium',
#  'HanWangKaiMediumPoIn1',
#  'Gill Sans MT Ext Condensed Bold',
#  'Century Gothic',
#  'AR CENA',
#  'Levenim MT',
#  'Avenir Next LT W04 Light',
#  'Edwardian Script ITC',
#  'Tw Cen MT Condensed',
#  'Vrinda',
#  'HanWangCC02',
#  'Leelawadee UI',
#  'Angsana New',
#  'Cumberland AMT',
#  'Bookman Old Style',
#  'Cumberland AMT',
#  'Bodoni MT',
#  'Adobe Fangsong Std',
#  'Kozuka Mincho Pro',
#  'Segoe UI',
#  'Courier New',
#  'Berlin Sans FB Demi',
#  'Franklin Gothic Demi',
#  'Adobe Naskh',
#  'Century Gothic',
#  'Simplified Arabic Fixed',
#  'Bell MT',
#  'Candara',
#  'Myriad Pro',
#  'Andalus',
#  'Bookman Old Style',
#  'Showcard Gothic',
#  'Monotype Corsiva',
#  'Aldhabi',
#  'Rage Italic',
#  'Kozuka Mincho Pr6N',
#  'HanWangKaiMediumPoIn2',
#  'OCR A Extended',
#  'Calibri',
#  'Vivaldi',
#  'Cooper Std',
#  'Microsoft PhagsPa',
#  'FreesiaUPC',
#  'Tw Cen MT Condensed Extra Bold',
#  'Webdings',
#  'Ebrima',
#  'Baskerville Old Face',
#  'Perpetua Titling MT',
#  'Arial',
#  'Courier New',
#  'Kozuka Mincho Pr6N',
#  'Berlin Sans FB',
#  'HanWangWCL09',
#  'Letter Gothic Std',
#  'Minion Pro',
#  'Microsoft Uighur',
#  'HanWangWCL06',
#  'Cumberland AMT',
#  'Tw Cen MT',
#  'Harrington',
#  'Matura MT Script Capitals',
#  'HanWangMingMediumPoIn1',
#  'IrisUPC',
#  'Comic Sans MS',
#  'HP Simplified',
#  'Noto Sans CJK TC',
#  'Cambria',
#  'Tunga',
#  'Californian FB',
#  'Tahoma',
#  'Chaparral Pro',
#  'Adobe Kaiti Std',
#  'Bookman Old Style',
#  'Freestyle Script',
#  'Myriad Hebrew',
#  'Bell MT',
#  'Eras Bold ITC',
#  'MV Boli',
#  'AR BONNIE',
#  'Lucida Sans Typewriter',
#  'Century Schoolbook',
#  'Lucida Console',
#  'Arial',
#  'Tunga',
#  'HanWangMingMediumPoIn3',
#  'Harlow Solid Italic',
#  'Tw Cen MT',
#  'Microsoft Tai Le',
#  'Gloucester MT Extra Condensed',
#  'Adobe Hebrew',
#  'Lucida Sans Typewriter',
#  'Lucida Fax',
#  'Corbel',
#  'Utsaah',
#  'AR DARLING',
#  'HP Simplified',
#  'Myriad Hebrew',
#  'AR DECODE',
#  'Myriad Pro',
#  'Onyx',
#  'Noto Sans CJK TC',
#  'Perpetua Titling MT',
#  'Agency FB',
#  'BrowalliaUPC',
#  'Niagara Solid',
#  'Minion Pro',
#  'Avenir Next LT W04 Regular',
#  'LilyUPC',
#  'Myanmar Text',
#  'Myriad Arabic',
#  'DilleniaUPC',
#  'Lucida Bright',
#  'Consolas',
#  'Lucida Fax',
#  'Nirmala UI',
#  'Franklin Gothic Medium',
#  'Comic Sans MS',
#  'HanWangWCL06',
#  'Vijaya',
#  'Vani',
#  'Perpetua Titling MT',
#  'Microsoft PhagsPa',
#  'Matura MT Script Capitals',
#  'Comic Sans MS',
#  'Arial Symbol',
#  'Shruti',
#  'Minion Pro',
#  'Myriad Pro',
#  'Kalinga',
#  'FangSong',
#  'Traditional Arabic',
#  'FreesiaUPC',
#  'Chaparral Pro',
#  'Perpetua Titling MT',
#  'WenYue GuDianMingChaoTi (Non-Commercial Use)',
#  'Adobe Ming Std',
#  'HP Simplified',
#  'Corbel',
#  'Eras Medium ITC',
#  'AR BONNIE',
#  'Modern No. 20',
#  'Arial',
#  'Microsoft Tai Le',
#  'JasmineUPC',
#  'Adobe Fan Heiti Std',
#  'HanWangMingMediumPoIn2',
#  'AR HERMANN',
#  'CordiaUPC',
#  'Perpetua',
#  'MS Reference Specialty',
#  'Adobe Devanagari',
#  'Constantia',
#  'Magneto',
#  'Thorndale AMT',
#  'Gisha',
#  'Estrangelo Edessa',
#  'HanWangMingMediumChuIn',
#  'Forte',
#  'Microsoft New Tai Lue',
#  'FreesiaUPC',
#  'Adobe Song Std',
#  'Thorndale AMT',
#  'Myriad Hebrew',
#  'Myriad Pro',
#  'Britannic Bold',
#  'Minion Pro',
#  'Elephant',
#  'David',
#  'Avenir Next LT W04 Light Italic',
#  'Times New Roman',
#  'Verdana',
#  'Avenir Next LT W04 Italic',
#  'Sylfaen',
#  'Blackadder ITC',
#  'Lucida Sans Typewriter',
#  'Engravers MT',
#  'Adobe Garamond Pro',
#  'AR DECODE',
#  'Book Antiqua',
#  'Verdana',
#  'Aparajita',
#  'Times New Roman',
#  'Bodoni MT',
#  'DaunPenh',
#  'Miriam Fixed',
#  'AR CHRISTY',
#  'Franklin Gothic Demi',
#  'Brush Script MT',
#  'Bell MT',
#  'HanWangKaiMediumPoIn3',
#  'Franklin Gothic Demi',
#  'Castellar',
#  'Angsana New',
#  'Candara',
#  'Californian FB',
#  'Kalinga',
#  'Lucida Bright',
#  'Baskerville Old Face',
#  'Mangal',
#  'Rockwell',
#  'Hobo Std',
#  'Calisto MT',
#  'Arial',
#  'Trebuchet MS',
#  'Kozuka Mincho Pr6N',
#  'Calibri',
#  'Shruti',
#  'Eras Demi ITC',
#  'KodchiangUPC',
#  'Adobe Arabic',
#  'Segoe UI Symbol',
#  'Berlin Sans FB Demi',
#  'Tahoma',
#  'Segoe Script',
#  'Tekton Pro',
#  'Minion Pro',
#  'Script MT Bold',
#  'French Script MT',
#  'Letter Gothic Std',
#  'Cumberland AMT',
#  'Nueva Std',
#  'Adobe Garamond Pro',
#  'JasmineUPC',
#  'Malgun Gothic',
#  'Tekton Pro',
#  'Browallia New',
#  'Yu Gothic',
#  'Adobe Devanagari',
#  'Gautami',
#  'Kozuka Gothic Pro',
#  'Adobe Arabic',
#  'Garamond',
#  'Rosewood Std',
#  'Orator Std',
#  'Leelawadee UI',
#  'Palatino Linotype',
#  'Parchment',
#  'Gabriola',
#  'Kristen ITC',
#  'HanWangWCL01',
#  'Franklin Gothic Book',
#  'Adobe Caslon Pro',
#  'Lucida Handwriting',
#  'Gadugi',
#  'Nueva Std',
#  'MYingHei_18030_C-Medium',
#  'Gill Sans MT',
#  'Aharoni',
#  'Tekton Pro',
#  'Gill Sans MT',
#  'Minion Pro',
#  'Copperplate Gothic Bold',
#  'Avenir Next Cyr W04',
#  'Lithos Pro',
#  'Avenir Next Cyr W04 Italic',
#  'Kozuka Mincho Pro',
#  'DokChampa',
#  'Lucida Sans',
#  'Courier New',
#  'Noto Sans CJK TC',
#  'Minion Pro',
#  'Rockwell',
#  'Microsoft Himalaya',
#  'Utsaah',
#  'OCR A Std',
#  'CSongGB18030C-Light',
#  'Mangal',
#  'Rockwell Condensed',
#  'SAS Monospace Bold',
#  'Segoe UI',
#  'Gill Sans Ultra Bold Condensed',
#  'Lucida Bright',
#  'Kozuka Gothic Pro',
#  'Times New Roman Symbol',
#  'Goudy Old Style',
#  'Tw Cen MT Condensed Extra Bold',
#  'Kartika',
#  'HanWangMingMedium',
#  'Charlemagne Std',
#  'HanWangKanTan',
#  'Adobe Myungjo Std',
#  'HanWangWCL05',
#  'Albany AMT',
#  'Tempus Sans ITC',
#  'Kozuka Mincho Pro',
#  'Kozuka Gothic Pr6N',
#  'Rod',
#  'Arial Unicode MS',
#  'Mistral',
#  'Wingdings',
#  'Kozuka Gothic Pro',
#  'Corbel',
#  'Chaparral Pro',
#  'MS Outlook',
#  'Century Gothic',
#  'Kozuka Mincho Pr6N',
#  'AR ESSENCE',
#  'Avenir Next LT W04',
#  'BrowalliaUPC',
#  'KodchiangUPC',
#  'Kozuka Gothic Pro',
#  'Vani',
#  'Birch Std',
#  'LilyUPC',
#  'Eras Bold ITC',
#  'Felix Titling',
#  'Adobe Hebrew',
#  'Comic Sans MS',
#  'Perpetua',
#  'Adobe Garamond Pro',
#  'Juice ITC',
#  'Leelawadee',
#  'Parchment',
#  'Kokila',
#  'IrisUPC',
#  'Segoe Print',
#  'Arial',
#  'Myriad Hebrew',
#  'Trajan Pro',
#  'Garamond',
#  'Adobe Caslon Pro',
#  'Lucida Sans',
#  'Raavi',
#  'Nyala',
#  'Nueva Std',
#  'Lucida Fax',
#  'KodchiangUPC',
#  'Bodoni MT',
#  'Bauhaus 93',
#  'Arial',
#  'Yu Gothic',
#  'Rockwell Extra Bold',
#  'Levenim MT',
#  'Century',
#  'HP Simplified',
#  'Lithos Pro',
#  'SAS Monospace',
#  'Kozuka Gothic Pro',
#  'Book Antiqua',
#  'High Tower Text',
#  'JasmineUPC',
#  'Kozuka Mincho Pr6N',
#  'Palatino Linotype',
#  'Shonar Bangla',
#  'Adobe Garamond Pro',
#  'Segoe UI',
#  'Vani',
#  'EucrosiaUPC',
#  'Constantia',
#  'Bodoni MT',
#  'Myriad Arabic',
#  'AR BLANCA',
#  'Adobe Fangsong Std',
#  'Kokila',
#  'Avenir Next LT W04',
#  'Palatino Linotype',
#  'Noto Sans Mono CJK TC',
#  'Bodoni MT',
#  'Calisto MT',
#  'Copperplate Gothic Bold',
#  'DFKai-SB',
#  'Kozuka Mincho Pr6N',
#  'Shonar Bangla',
#  'Brush Script Std',
#  'Segoe UI',
#  'HanWang SinSongThin-Gb5',
#  'Century Schoolbook',
#  'Lucida Sans',
#  'Sakkal Majalla',
#  'HP Simplified',
#  'Gill Sans MT',
#  'AvantGarde LT ExtraLight',
#  'Minion Pro',
#  'Trajan Pro',
#  'Lucida Sans Unicode',
#  'Minion Pro',
#  'Minion Pro',
#  'Simplified Arabic',
#  'Kozuka Mincho Pro',
#  'Letter Gothic Std',
#  'LilyUPC',
#  'Sakkal Majalla',
#  'Vivaldi',
#  'Kozuka Gothic Pro',
#  'Nueva Std',
#  'Algerian',
#  'Tekton Pro',
#  'Century Schoolbook',
#  'Albany AMT',
#  'Lao UI',
#  'Century Gothic',
#  'Garamond',
#  'Gautami',
#  'Iskoola Pota',
#  'HanWangCC15',
#  'Lucida Sans',
#  'Leelawadee UI',
#  'HanWangMingBlack',
#  'HanWangGSolid06cut1',
#  'Gisha',
#  'Cooper Std',
#  'KaiTi',
#  'AR ESSENCE',
#  'Adobe Caslon Pro',
#  'Franklin Gothic Heavy',
#  'LilyUPC',
#  'Segoe Script',
#  'Lucida Bright',
#  'Elephant',
#  'IrisUPC',
#  'EucrosiaUPC',
#  'Century',
#  'Leelawadee UI',
#  'AR DARLING',
#  'Cordia New',
#  'Noto Sans Mono CJK TC',
#  'Old English Text MT',
#  'Viner Hand ITC',
#  'Adobe Devanagari',
#  'Minion Pro',
#  'Lucida Fax',
#  'Poplar Std',
#  'Tw Cen MT',
#  'Georgia',
#  'Nueva Std',
#  'Castellar',
#  'Stencil',
#  'Lucida Fax',
#  'Californian FB',
#  'Bell MT',
#  'Niagara Solid',
#  'Browallia New',
#  'Thorndale AMT',
#  'Cordia New',
#  'Simplified Arabic',
#  'Magneto',
#  'Microsoft Uighur',
#  'HanWangMingHeavy',
#  'HanWangWCL08',
#  'Myriad Pro',
#  'Bodoni MT',
#  'Kozuka Gothic Pro',
#  'Franklin Gothic Book',
#  'Letter Gothic Std',
#  'Adobe Caslon Pro',
#  'Palatino Linotype',
#  'Adobe Caslon Pro',
#  'Forte',
#  'Leelawadee UI',
#  'Adobe Caslon Pro',
#  'HP Simplified',
#  'Adobe Devanagari',
#  'Rockwell',
#  'Kozuka Mincho Pro',
#  'HanWangKaiMediumChuIn',
#  'Kunstler Script',
#  'Copperplate Gothic Light',
#  'Calibri',
#  'Wide Latin',
#  'WenyueType GutiFangsong (Non-Commercial Use)',
#  'Browallia New',
#  'Lithos Pro',
#  'Narkisim',
#  'DilleniaUPC',
#  'High Tower Text',
#  'Kozuka Mincho Pro',
#  'Consolas',
#  'Minion Pro',
#  'Segoe UI',
#  'Chaparral Pro',
#  'Gill Sans Ultra Bold Condensed',
#  'Engravers MT',
#  'Myriad Pro',
#  'OCR A Std',
#  'Myriad Hebrew',
#  'HanWangMingBold',
#  'AR DESTINE',
#  'Blackoak Std',
#  'Chaparral Pro',
#  'Charlemagne Std',
#  'Harrington',
#  'Haettenschweiler',
#  'MS Reference Specialty',
#  'Colonna MT',
#  'Kozuka Gothic Pr6N',
#  'Adobe Arabic',
#  'AvantGarde LT ExtraLight',
#  'Kozuka Gothic Pro',
#  'Khmer UI',
#  'Gloucester MT Extra Condensed',
#  'Tempus Sans ITC',
#  'Bernard MT Condensed',
#  'Adobe Garamond Pro',
#  'Candara',
#  'AR CARTER',
#  'Onyx',
#  'CordiaUPC',
#  'Goudy Stout',
#  'KodchiangUPC',
#  'Adobe Garamond Pro',
#  'Tekton Pro',
#  'Franklin Gothic Demi Cond',
#  'Minion Pro',
#  'Lucida Sans Typewriter',
#  'Utsaah',
#  'MYingHei_18030_C-MediumHWL',
#  'Impact',
#  'Consolas',
#  'Script MT Bold',
#  'Poor Richard',
#  'Noto Sans CJK TC',
#  'Prestige Elite Std',
#  'Albany AMT',
#  'Informal Roman',
#  'Cambria',
#  'Nueva Std',
#  'Franklin Gothic Demi',
#  'Nueva Std',
#  'Trebuchet MS',
#  'Kozuka Gothic Pro',
#  'Kozuka Mincho Pro',
#  'Pristina',
#  'Vladimir Script',
#  'CordiaUPC',
#  'Kozuka Gothic Pr6N',
#  'Wingdings 3',
#  'Tekton Pro',
#  'Kozuka Gothic Pr6N',
#  'HanWangHeiHeavy',
#  'Vani',
#  'HanWangWCL08',
#  'Avenir Next Cyr W04 Regular',
#  'Mesquite Std',
#  'Bradley Hand ITC',
#  'Calibri',
#  'Ebrima',
#  'Noto Sans CJK TC',
#  'AngsanaUPC',
#  'Playbill',
#  'Century Gothic',
#  'Cooper Black',
#  'Verdana',
#  'Adobe Heiti Std',
#  'Calibri',
#  'Kozuka Gothic Pr6N',
#  'Vladimir Script',
#  'HanWang WeiBeiMedium-Gb5',
#  'Myriad Pro',
#  'Aparajita',
#  'Myriad Hebrew',
#  'Myriad Pro',
#  'Trebuchet MS',
#  'Century Schoolbook',
#  'Bodoni MT',
#  'Wingdings 3',
#  'Footlight MT Light',
#  'Bauhaus 93',
#  'Minion Pro',
#  'Yu Gothic',
#  'Perpetua',
#  'Adobe Heiti Std',
#  'Times New Roman Symbol',
#  'Algerian',
#  'Centaur',
#  'Rosewood Std',
#  'Book Antiqua',
#  'Franklin Gothic Heavy',
#  'MS Reference Sans Serif',
#  'Segoe UI',
#  'HanWangShinSuMedium',
#  'Myriad Arabic',
#  'Urdu Typesetting',
#  'AR DELANEY',
#  'Browallia New',
#  'Nueva Std',
#  'Myriad Arabic',
#  'Gill Sans MT Condensed',
#  'Marlett',
#  'Candara',
#  'Stencil Std',
#  'Yu Mincho',
#  'Bookshelf Symbol 7',
#  'Cooper Std',
#  'Bernard MT Condensed',
#  'Bodoni MT',
#  'Microsoft Sans Serif',
#  'Corbel',
#  'Poplar Std',
#  'French Script MT',
#  'Symbol',
#  'Kozuka Mincho Pro',
#  'Tw Cen MT',
#  'Gill Sans MT',
#  'Constantia',
#  'Kozuka Mincho Pr6N',
#  'Myriad Hebrew',
#  'Gadugi',
#  'Nirmala UI',
#  'EucrosiaUPC',
#  'Times New Roman Uni',
#  'Arial',
#  'Leelawadee',
#  'Gigi',
#  'Calisto MT',
#  'Eras Light ITC',
#  'Nirmala UI',
#  'HanWangWCL10',
#  'Georgia',
#  'HanWangWCL07',
#  'Segoe UI',
#  'Courier New',
#  'Kozuka Mincho Pr6N',
#  'Giddyup Std',
#  'Bodoni MT',
#  'Franklin Gothic Book',
#  'Curlz MT',
#  'Bodoni MT',
#  'HeiT',
#  'CordiaUPC',
#  'AR JULIAN',
#  'Felix Titling',
#  'Book Antiqua',
#  'Adobe Devanagari',
#  'Bodoni MT',
#  'Book Antiqua',
#  'David',
#  'Bradley Hand ITC',
#  'Centaur',
#  'AR DELANEY',
#  'Goudy Old Style',
#  'Bodoni MT',
#  'Kozuka Gothic Pr6N',
#  'Segoe UI',
#  'Harlow Solid Italic',
#  'Garamond',
#  'Khmer UI',
#  'Bookman Old Style',
#  'Century Gothic',
#  'Agency FB',
#  'CSong3HK',
#  'Tw Cen MT Condensed',
#  'Orator Std',
#  'Khmer UI',
#  'Nueva Std',
#  'Adobe Arabic',
#  'Adobe Garamond Pro',
#  'Adobe Myungjo Std',
#  'Imprint MT Shadow',
#  'Aparajita',
#  'Rage Italic',
#  'Old English Text MT',
#  'Bodoni MT',
#  'Shonar Bangla',
#  'Microsoft Yi Baiti',
#  'Century Schoolbook',
#  'Berlin Sans FB',
#  'Gill Sans MT',
#  'Perpetua',
#  'Letter Gothic Std',
#  'Myriad Pro',
#  'Candara',
#  'Adobe Devanagari',
#  'Gill Sans MT',
#  'Cordia New',
#  'Blackoak Std',
#  'Arial',
#  'Kozuka Gothic Pr6N',
#  'Lithos Pro',
#  'HanWangZonYi',
#  'Arial',
#  'MT Extra',
#  'AvantGarde LT ExtraLight',
#  'Lucida Sans',
#  'Goudy Old Style',
#  'Bookshelf Symbol 7',
#  'Adobe Hebrew',
#  'Myriad Arabic',
#  'AvantGarde LT ExtraLight',
#  'Utsaah',
#  'Chaparral Pro',
#  'Adobe Hebrew',
#  'High Tower Text',
#  'Arial',
#  'Myriad Pro',
#  'Chaparral Pro',
#  'Nueva Std',
#  'Chaparral Pro',
#  'Times New Roman',
#  'Avenir Next Cyr W04 Light',
#  'Stencil Std',
#  'AR CENA',
#  'Kozuka Mincho Pro',
#  'Urdu Typesetting',
#  'Century Schoolbook',
#  'CSong3HK',
#  'Lucida Bright',
#  'Myriad Pro',
#  'Rockwell Condensed',
#  'Letter Gothic Std',
#  'Chiller',
#  'HanWangWCL05',
#  'Pristina',
#  'Noto Sans CJK TC',
#  'HanWangYenLight',
#  'Candara',
#  'Minion Pro',
#  'Adobe Hebrew',
#  'Mesquite Std',
#  'Lucida Sans Typewriter',
#  'Adobe Kaiti Std',
#  'Latha',
#  'Nueva Std',
#  'Lucida Calligraphy',
#  'Bodoni MT',
#  'Adobe Garamond Pro',
#  'Myriad Pro',
#  'Wingdings 2',
#  'Lucida Fax',
#  'Times New Roman',
#  'Rockwell',
#  'Palace Script MT',
#  'Myriad Pro',
#  'Adobe Arabic',
#  'Orator Std',
#  'Arial Rounded MT Bold',
#  'Bodoni MT',
#  'Imprint MT Shadow',
#  'Lucida Sans Typewriter',
#  'Calisto MT',
#  'Lucida Sans',
#  'Prestige Elite Std',
#  'Kozuka Gothic Pr6N',
#  'Kozuka Gothic Pr6N',
#  'Myriad Arabic',
#  'HanWangKanDaYan',
#  'Gill Sans MT Ext Condensed Bold',
#  'Bodoni MT',
#  'Minion Pro',
#  'Noto Sans CJK TC',
#  'Bodoni MT',
#  'Nueva Std',
#  'Arial Symbol',
#  'HP Simplified',
#  'Bell MT',
#  'HanWangKaiMediumChuIn',
#  'Ravie',
#  'Myriad Hebrew',
#  'Showcard Gothic',
#  'Rockwell',
#  'Edwardian Script ITC',
#  'Maiandra GD',
#  'Myriad Arabic',
#  'Lucida Handwriting',
#  'Kozuka Mincho Pr6N',
#  'AR BERKLEY',
#  'HanWangMingMediumChuIn',
#  'Gabriola',
#  'Colonna MT',
#  'Rockwell Condensed',
#  'Lucida Bright',
#  'Segoe UI',
#  'Arial',
#  'Khmer UI',
#  'AR CARTER',
#  'Blackadder ITC',
#  'AR HERMANN',
#  'Playbill',
#  'Lucida Calligraphy',
#  'Franklin Gothic Medium Cond',
#  'Lucida Sans',
#  'Miriam',
#  'Minion Pro',
#  'IrisUPC',
#  'Trajan Pro',
#  'Noto Sans CJK TC',
#  'Perpetua',
#  'Gigi',
#  'Kozuka Gothic Pr6N',
#  'Adobe Naskh',
#  'Adobe Devanagari',
#  'HP Simplified',
#  'Nirmala UI',
#  'Kozuka Mincho Pr6N',
#  'Arial',
#  'Bodoni MT',
#  'Book Antiqua',
#  'Bodoni MT',
#  'Noto Sans CJK TC',
#  'Bookman Old Style',
#  'Viner Hand ITC',
#  ...]

# %%
df = pd.read_csv('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-9103c3e07843> in <module>()
# ----> 1 df = pd.read_xlsx('http://data.taipower.com.tw/opendata/apply/file/d018001/台灣電力公司_電價成本.xlsx')
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
df.head()
# Out:
#           檔案名稱                                               下載網址
# 0  台灣電力公司_電價成本  http://data.taipower.com.tw/opendata/apply/fil...

# %%
df.values
# Out:
# array([['台灣電力公司_電價成本',
#         'http://data.taipower.com.tw/opendata/apply/file/d018001/台灣電力公司_電價成本.xlsx']],
#       dtype=object)
